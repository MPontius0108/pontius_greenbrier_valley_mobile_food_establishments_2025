# %%
import pandas as pd
from io import StringIO

data = """Item Name,Price,Description,Category
Pretzel - Regular,$5.00,,Pretzel
Pretzel - Cinnamon Sugar,$6.00,,Pretzel
Pretzel - Garlic Parm,$6.00,,Pretzel
Pretzelroni Roll,$8.00,"Freshly sliced pepperoni and mozzarella cheese wrapped in our signature pretzel dough",Specialty
Dip - Cheese,$1.00,,Dip
Dip - Honey Mustard,$1.00,,Dip
Dip - Marinara,$1.00,,Dip
Dip - Sweet Cream Cheese,$1.00,,Dip
Drink - Country Colada,,,Drink
Drink - Harvest Sunset,,,Drink
"Drink Note: Loaded teas from The Tea Shack",,,"(pineapple & pina colada)",Note
"Drink Note: Loaded teas from The Tea Shack",,,"(red raspberry & peach)",Note
"""

# Read into DataFrame
df = pd.read_csv(StringIO(data))

output_path = "C:/Users/user/workspace/c11/Capstone/Data/Menus/smash_pots_menu.xlsx"

df.to_excel(output_path, index=False)

print(df)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[19], line 20
#       4 data = """Item Name,Price,Description,Category
#       5 Pretzel - Regular,$5.00,,Pretzel
#       6 Pretzel - Cinnamon Sugar,$6.00,,Pretzel
#    (...)
#      16 "Drink Note: Loaded teas from The Tea Shack",,,"(red raspberry & peach)",Note
#      17 """
#      19 # Read into DataFrame
# ---> 20 df = pd.read_csv(StringIO(data))
#      22 output_path = "C:/Users/user/workspace/c11/Capstone/Data/Menus/smash_pots_menu.xlsx"
#      24 df.to_excel(output_path, index=False)
#
# ...

# %%
import pandas as pd
from io import StringIO

data = """Item Name,Price,Description,Category
Italian Ice - Small,$5.00,,Italian Ice
Italian Ice - Medium,$6.00,,Italian Ice
Italian Ice - Large,$7.00,,Italian Ice
Pretzel,$5.00,,Snack
Pretzel with Cheese,$6.00,,Snack
Cake (slice),$3.00,,Dessert
Coke (bottle),$2.00,,Drink
Water,$1.00,,Drink
"Flavor: Blueberry",,,Flavor
"Flavor: Cherry",,,Flavor
"Flavor: Mango",,,Flavor
"Flavor: Lemon",,,Flavor
"Flavor: Watermelon",,,Flavor
"Flavor: Cotton Candy",,,Flavor
"""
# Read into DataFrame
df = pd.read_csv(StringIO(data))

# Save to Excel
output_path = "C:/Users/user/workspace/c11/Capstone/Data/Menus/little_jimmys_italian_ice_menu.xlsx"
df.to_excel(output_path, index=False)

print(df)
# Out:
#                Item Name  Price  Description     Category
# 0    Italian Ice - Small  $5.00          NaN  Italian Ice
# 1   Italian Ice - Medium  $6.00          NaN  Italian Ice
# 2    Italian Ice - Large  $7.00          NaN  Italian Ice
# 3                Pretzel  $5.00          NaN        Snack
# 4    Pretzel with Cheese  $6.00          NaN        Snack
# 5           Cake (slice)  $3.00          NaN      Dessert
# 6          Coke (bottle)  $2.00          NaN        Drink
# 7                  Water  $1.00          NaN        Drink
# 8      Flavor: Blueberry    NaN          NaN       Flavor
# 9         Flavor: Cherry    NaN          NaN       Flavor
# 10         Flavor: Mango    NaN          NaN       Flavor
# 11         Flavor: Lemon    NaN          NaN       Flavor
# 12    Flavor: Watermelon    NaN          NaN       Flavor
# 13  Flavor: Cotton Candy    NaN          NaN       Flavor
