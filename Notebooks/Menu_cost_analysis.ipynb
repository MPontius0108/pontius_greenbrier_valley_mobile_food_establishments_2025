# %%
import pandas as pd
from io import StringIO

# -------------------------------------------------
# 1. Paste the CSV text (exactly as above)
# -------------------------------------------------
csv_text = """Menu Item,Component,Ingredient,Amount per Portion,Portion Unit,Wholesale Price (per Base Unit),Cost per Portion Amount,Subtotal per Component
Chicken Biscuit,Biscuit,Flour,0.25,cup,$0.60/lb,$0.04,$0.47
Chicken Biscuit,Biscuit,Baking Powder,0.13,tbsp,$4.50/lb,$0.01,
Chicken Biscuit,Biscuit,Salt,0.13,tbsp,$0.75/lb,$0.00,
Chicken Biscuit,Biscuit,Butter,1.00,tbsp,$2.55/lb,$0.08,
Chicken Biscuit,Biscuit,Buttermilk,0.13,cup,$4.00/gal,$0.26,
Chicken Biscuit,Fried Chicken Cutlet,Chicken Breast,0.50,lb,$3.00/lb,$1.50,$2.02
Chicken Biscuit,Fried Chicken Cutlet,Dill Pickle Juice,0.25,cup,$5.00/gal,$0.10,
Chicken Biscuit,Fried Chicken Cutlet,Egg,0.25,egg,$0.21/egg,$0.05,
Chicken Biscuit,Fried Chicken Cutlet,Whole Milk,0.13,cup,$2.75/gal,$0.09,
Chicken Biscuit,Fried Chicken Cutlet,Franks Red Hot,0.25,tbsp,$13.50/gal,$0.03,
Chicken Biscuit,Fried Chicken Cutlet,Powdered Sugar,0.50,tbsp,$0.75/lb,$0.01,
Chicken Biscuit,Fried Chicken Cutlet,Paprika,0.25,tbsp,$7.00/lb,$0.04,
Chicken Biscuit,Fried Chicken Cutlet,Salt,0.25,tbsp,$0.75/lb,$0.00,
Chicken Biscuit,Fried Chicken Cutlet,Black Pepper,0.25,tbsp,$8.00/lb,$0.05,
Chicken Biscuit,Fried Chicken Cutlet,Garlic Salt,0.25,tbsp,$5.25/lb,$0.04,
Chicken Biscuit,Fried Chicken Cutlet,Frying Oil,-,-,Negligible,$0.00,
"Total per Chicken Biscuit Portion",-, -, -, -, -, -, **$2.49**
Biscuits n Chicken Gravy,Biscuit,Flour,0.25,cup,$0.60/lb,$0.04,$0.47
Biscuits n Chicken Gravy,Biscuit,Baking Powder,0.13,tbsp,$4.50/lb,$0.01,
Biscuits n Chicken Gravy,Biscuit,Salt,0.13,tbsp,$0.75/lb,$0.00,
Biscuits n Chicken Gravy,Biscuit,Butter,1.00,tbsp,$2.55/lb,$0.08,
Biscuits n Chicken Gravy,Biscuit,Buttermilk,0.13,cup,$4.00/gal,$0.26,
Biscuits n Chicken Gravy,Chicken Gravy,Chicken Drippings,2.00,tbsp,$0.00 (byproduct),$0.00,$1.00
Biscuits n Chicken Gravy,Chicken Gravy,Butter,2.00,tbsp,$2.55/lb,$0.16,
Biscuits n Chicken Gravy,Chicken Gravy,Flour,0.25,cup,$0.60/lb,$0.04,
Biscuits n Chicken Gravy,Chicken Gravy,Whole Milk,2.00,cup,$2.75/gal,$1.37,
Biscuits n Chicken Gravy,Chicken Gravy,Salt,1.00,tbsp,$0.75/lb,$0.02,
Biscuits n Chicken Gravy,Chicken Gravy,Black Pepper,1.00,tbsp,$8.00/lb,$0.20,
Biscuits n Chicken Gravy,Chicken Gravy,Chicken Boullion,1.00,tsp,$6.00/lb,$0.04,
"Total per Biscuits n Chicken Gravy Portion",-, -, -, -, -, -, **$1.47**
4 pc Tenders,Fried Chicken Tenderloins,Chicken Breast,0.50,lb,$3.00/lb,$1.50,$1.95
4 pc Tenders,Fried Chicken Tenderloins,Dill Pickle Juice,0.25,cup,$5.00/gal,$0.10,
4 pc Tenders,Fried Chicken Tenderloins,Egg,0.25,egg,$0.21/egg,$0.05,
4 pc Tenders,Fried Chicken Tenderloins,Whole Milk,0.13,cup,$2.75/gal,$0.09,
4 pc Tenders,Fried Chicken Tenderloins,Franks Red Hot,0.25,tbsp,$13.50/gal,$0.03,
4 pc Tenders,Fried Chicken Tenderloins,Powdered Sugar,0.50,tbsp,$0.75/lb,$0.01,
4 pc Tenders,Fried Chicken Tenderloins,Paprika,0.25,tbsp,$7.00/lb,$0.04,
4 pc Tenders,Fried Chicken Tenderloins,Salt,0.25,tbsp,$0.75/lb,$0.00,
4 pc Tenders,Fried Chicken Tenderloins,Black Pepper,0.25,tbsp,$8.00/lb,$0.05,
4 pc Tenders,Fried Chicken Tenderloins,Garlic Salt,0.25,tbsp,$5.25/lb,$0.04,
4 pc Tenders,Fried Chicken Tenderloins,Frying Oil,-,-,Negligible,$0.00,
"Total per 4 pc Tenders Portion",-, -, -, -, -, -, **$1.95**
Chicken Sandwich,Fried Chicken Cutlet,Chicken Breast,0.50,lb,$3.00/lb,$1.50,$1.95
Chicken Sandwich,Fried Chicken Cutlet,Dill Pickle Juice,0.25,cup,$5.00/gal,$0.10,
Chicken Sandwich,Fried Chicken Cutlet,Egg,0.25,egg,$0.21/egg,$0.05,
Chicken Sandwich,Fried Chicken Cutlet,Whole Milk,0.13,cup,$2.75/gal,$0.09,
Chicken Sandwich,Fried Chicken Cutlet,Franks Red Hot,0.25,tbsp,$13.50/gal,$0.03,
Chicken Sandwich,Fried Chicken Cutlet,Powdered Sugar,0.50,tbsp,$0.75/lb,$0.01,
Chicken Sandwich,Fried Chicken Cutlet,Paprika,0.25,tbsp,$7.00/lb,$0.04,
Chicken Sandwich,Fried Chicken Cutlet,Salt,0.25,tbsp,$0.75/lb,$0.00,
Chicken Sandwich,Fried Chicken Cutlet,Black Pepper,0.25,tbsp,$8.00/lb,$0.05,
Chicken Sandwich,Fried Chicken Cutlet,Garlic Salt,0.25,tbsp,$5.25/lb,$0.04,
Chicken Sandwich,Fried Chicken Cutlet,Frying Oil,-,-,Negligible,$0.00,
Chicken Sandwich,Sandwich Bun,Sandwich Buns,1.00,sandwich bun,$0.30/each,$0.30,$0.35
Chicken Sandwich,Sandwich Bun,Butter,0.50,tbsp,$2.55/lb,$0.04,
Chicken Sandwich,Dill Pickle Chips,Dill Pickles,0.01,gallon jar,$20.00/gal jar,$0.20,$0.20
"Total per Chicken Sandwich Portion",-, -, -, -, -, -, **$2.50**
Chicken n Dumplings,Dumpling Broth,Chicken Broth,4.00,cup,$1.50/gal,$1.88,$2.41
Chicken n Dumplings,Dumpling Broth,Salt,0.25,tbsp,$0.75/lb,$0.00,
Chicken n Dumplings,Dumpling Broth,Pepper,0.25,tbsp,$8.00/lb,$0.05,
Chicken n Dumplings,Dumpling Broth,Chicken Breast,0.25,lb,$3.00/lb,$0.75,
Chicken n Dumplings,Dumpling Broth,Carrot,1.25,oz,$0.50/lb ($0.04/oz),$0.05,
Chicken n Dumplings,Dumpling Broth,Celery,1.25,oz,$0.50/lb ($0.04/oz),$0.05,
Chicken n Dumplings,Dumpling Broth,Yellow Onion,0.50,oz,$0.50/lb ($0.04/oz),$0.02,
Chicken n Dumplings,Dumplings,Flour,0.50,cup,$0.60/lb,$0.08,$0.95
Chicken n Dumplings,Dumplings,Baking Powder,0.25,tbsp,$4.50/lb,$0.03,
Chicken n Dumplings,Dumplings,Salt,0.25,tbsp,$0.75/lb,$0.00,
Chicken n Dumplings,Dumplings,Butter,2.00,tbsp,$2.55/lb,$0.16,
Chicken n Dumplings,Dumplings,Buttermilk,0.25,cup,$4.00/gal,$0.50,
"Total per Chicken n Dumplings Portion",-, -, -, -, -, -, **$3.36**
Family Combo,Rotisserie Chicken,Whole Chicken,2.25,lb,$1.65/lb,$3.71,$4.01
Family Combo,Rotisserie Chicken,Olive Oil,1.50,tbsp,$0.20/oz (~$0.10/tbsp),$0.15,
Family Combo,Rotisserie Chicken,Salt,1.00,tbsp,$0.75/lb,$0.02,
Family Combo,Rotisserie Chicken,Pepper,1.00,tbsp,$8.00/lb,$0.20,
Family Combo,Rotisserie Chicken,Garlic Salt,1.00,tbsp,$5.25/lb,$0.16,
Family Combo,Rotisserie Chicken,Parsley,1.00,tbsp,$6.00/lb,$0.10,
Family Combo,Rotisserie Chicken,Rosemary,1.00,tbsp,$8.00/lb,$0.13,
Family Combo,Rotisserie Chicken,Butter,1.50,tbsp,$2.55/lb,$0.12,
Family Combo,Dumpling Broth,Chicken Broth,4.00,cup,$1.50/gal,$1.88,$2.41
Family Combo,Dumpling Broth,Salt,0.25,tbsp,$0.75/lb,$0.00,
Family Combo,Dumpling Broth,Pepper,0.25,tbsp,$8.00/lb,$0.05,
Family Combo,Dumpling Broth,Chicken Breast,0.25,lb,$3.00/lb,$0.75,
Family Combo,Dumpling Broth,Carrot,1.25,oz,$0.50/lb ($0.04/oz),$0.05,
Family Combo,Dumpling Broth,Celery,1.25,oz,$0.50/lb ($0.04/oz),$0.05,
Family Combo,Dumpling Broth,Yellow Onion,0.50,oz,$0.50/lb ($0.04/oz),$0.02,
Family Combo,Dumplings,Flour,0.50,cup,$0.60/lb,$0.08,$0.95
Family Combo,Dumplings,Baking Powder,0.25,tbsp,$4.50/lb,$0.03,
Family Combo,Dumplings,Salt,0.25,tbsp,$0.75/lb,$0.00,
Family Combo,Dumplings,Butter,2.00,tbsp,$2.55/lb,$0.16,
Family Combo,Dumplings,Buttermilk,0.25,cup,$4.00/gal,$0.50,
"Total per Family Combo Portion",-, -, -, -, -, -, **$7.37**
Wedges,Potato Wedges,Potatoes,1.00,potato,$0.80/lb (~$0.50 each),$0.50,$0.80
Wedges,Potato Wedges,Whole Milk,0.25,cup,$2.75/gal,$0.17,
Wedges,Potato Wedges,Egg,0.25,egg,$0.21/egg,$0.05,
Wedges,Potato Wedges,Flour,0.25,cup,$0.60/lb,$0.04,
Wedges,Potato Wedges,Cornstarch,0.50,tbsp,$0.80/lb,$0.01,
Wedges,Potato Wedges,Seasoned Salt,0.25,tbsp,$5.25/lb,$0.04,
Wedges,Potato Wedges,Black Pepper,0.25,tbsp,$8.00/lb,$0.05,
Wedges,Potato Wedges,Garlic Salt,0.25,tbsp,$5.25/lb,$0.04,
Wedges,Potato Wedges,Paprika,0.25,tbsp,$7.00/lb,$0.04,
Wedges,Potato Wedges,Parsley,0.25,tbsp,$6.00/lb,$0.03,
Wedges,Potato Wedges,Frying Oil,-,-,Negligible,$0.00,
"Total per Wedges Portion",-, -, -, -, -, -, **$0.80**
Chicken Gravy,Chicken Gravy,Chicken Drippings,1.00,tbsp,$0.00 (byproduct),$0.00,$0.62
Chicken Gravy,Chicken Gravy,Butter,1.00,tbsp,$2.55/lb,$0.08,
Chicken Gravy,Chicken Gravy,Flour,0.13,cup,$0.60/lb,$0.02,
Chicken Gravy,Chicken Gravy,Whole Milk,1.00,cup,$2.75/gal,$0.68,
Chicken Gravy,Chicken Gravy,Salt,0.50,tbsp,$0.75/lb,$0.01,
Chicken Gravy,Chicken Gravy,Black Pepper,0.50,tbsp,$8.00/lb,$0.10,
Chicken Gravy,Chicken Gravy,Chicken Boullion,0.50,tsp,$6.00/lb,$0.02,
"Total per Chicken Gravy Portion",-, -, -, -, -, -, **$0.62**
Biscuits,Biscuit,Flour,0.25,cup,$0.60/lb,$0.04,$0.47
Biscuits,Biscuit,Baking Powder,0.13,tbsp,$4.50/lb,$0.01,
Biscuits,Biscuit,Salt,0.13,tbsp,$0.75/lb,$0.00,
Biscuits,Biscuit,Butter,1.00,tbsp,$2.55/lb,$0.08,
Biscuits,Biscuit,Buttermilk,0.13,cup,$4.00/gal,$0.26,
"Total per Biscuits Portion",-, -, -, -, -, -, **$0.47**
Soda,Soda,Soda (can),1.00,can,$0.50/can,$0.50,$0.50
Soda,Soda,Ice,-,-,Negligible,$0.00,
"Total per Soda Portion",-, -, -, -, -, -, **$0.50**
Water,Water,Water (bottle),1.00,bottle,$0.80/bottle,$0.80,$0.80
Water,Water,Ice,-,-,Negligible,$0.00,
"Total per Water Portion",-, -, -, -, -, -, **$0.80**
Sweet Tea,Sweet Tea,Sweet Tea (bottle),1.00,bottle,$0.80/bottle,$0.80,$0.80
Sweet Tea,Sweet Tea,Ice,-,-,Negligible,$0.00,
"Total per Sweet Tea Portion",-, -, -, -, -, -, **$0.80**"""   # <-- paste the ENTIRE CSV here (replace the ellipsis with the full content)

# -------------------------------------------------
# 2. Load & clean
# -------------------------------------------------
df = pd.read_csv(StringIO(csv_text))
df['Amount per Portion'] = pd.to_numeric(df['Amount per Portion'], errors='coerce')
df['Cost per Portion Amount'] = pd.to_numeric(df['Cost per Portion Amount'].replace('[\$,]', '', regex=True), errors='coerce')
df['Subtotal per Component'] = pd.to_numeric(df['Subtotal per Component'].replace('[\$,]', '', regex=True), errors='coerce')

# -------------------------------------------------
# 3. Export to Excel (with bold totals)
# -------------------------------------------------
output_path = r"C:/Users/user/workspace/c11/Capstone/Data/food_truck_cost_breakdown.xlsx"

output_file = "food_truck_cost_breakdown.xlsx"
with pd.ExcelWriter(output_file, engine='openpyxl') as writer:
    df.to_excel(writer, index=False, sheet_name='Cost Breakdown')

    # Bold the "Total per …" rows
    workbook = writer.book
    worksheet = writer.sheets['Cost Breakdown']
    for row in worksheet.iter_rows(min_row=2, max_row=worksheet.max_row):
        if row[0].value and 'Total per' in str(row[0].value):
            for cell in row:
                cell.font = cell.font.copy(bold=True)

print(f"Excel saved: {output_file}")
# Out:
# Excel saved: food_truck_cost_breakdown.xlsx
# C:\Users\user\AppData\Local\Temp\ipykernel_8424\2879983216.py:158: DeprecationWarning: Call to deprecated function copy (Use copy(obj) or cell.obj = cell.obj + other).
#   cell.font = cell.font.copy(bold=True)

# %%
import pandas as pd
from io import StringIO
import os
from pathlib import Path

# ================================================
# 1. CUSTOMIZE THIS PATH (use forward slashes or raw strings)
# ================================================
# Option A: Full absolute path (recommended for reliability)
output_path = r"C:/Users/user/workspace/c11/Capstone/Data/food_truck_cost_breakdown.xlsx"

# Option B: Relative to current script (e.g., save in same folder)
# output_path = "food_truck_cost_breakdown.xlsx"

# Option C: Desktop
# output_path = str(Path.home() / "Desktop" / "food_truck_cost_breakdown.xlsx")

# ================================================
# 2. Paste the FULL CSV data here (from previous message)
# ================================================
csv_text = """Menu Item,Component,Ingredient,Amount per Portion,Portion Unit,Wholesale Price (per Base Unit),Cost per Portion Amount,Subtotal per Component
Chicken Biscuit,Biscuit,Flour,0.25,cup,$0.60/lb,$0.04,$0.47
Chicken Biscuit,Biscuit,Baking Powder,0.13,tbsp,$4.50/lb,$0.01,
Chicken Biscuit,Biscuit,Salt,0.13,tbsp,$0.75/lb,$0.00,
Chicken Biscuit,Biscuit,Butter,1.00,tbsp,$2.55/lb,$0.08,
Chicken Biscuit,Biscuit,Buttermilk,0.13,cup,$4.00/gal,$0.26,
Chicken Biscuit,Fried Chicken Cutlet,Chicken Breast,0.50,lb,$3.00/lb,$1.50,$2.02
Chicken Biscuit,Fried Chicken Cutlet,Dill Pickle Juice,0.25,cup,$5.00/gal,$0.10,
Chicken Biscuit,Fried Chicken Cutlet,Egg,0.25,egg,$0.21/egg,$0.05,
Chicken Biscuit,Fried Chicken Cutlet,Whole Milk,0.13,cup,$2.75/gal,$0.09,
Chicken Biscuit,Fried Chicken Cutlet,Franks Red Hot,0.25,tbsp,$13.50/gal,$0.03,
Chicken Biscuit,Fried Chicken Cutlet,Powdered Sugar,0.50,tbsp,$0.75/lb,$0.01,
Chicken Biscuit,Fried Chicken Cutlet,Paprika,0.25,tbsp,$7.00/lb,$0.04,
Chicken Biscuit,Fried Chicken Cutlet,Salt,0.25,tbsp,$0.75/lb,$0.00,
Chicken Biscuit,Fried Chicken Cutlet,Black Pepper,0.25,tbsp,$8.00/lb,$0.05,
Chicken Biscuit,Fried Chicken Cutlet,Garlic Salt,0.25,tbsp,$5.25/lb,$0.04,
Chicken Biscuit,Fried Chicken Cutlet,Frying Oil,-,-,Negligible,$0.00,
"Total per Chicken Biscuit Portion",-, -, -, -, -, -, **$2.49**
Biscuits n Chicken Gravy,Biscuit,Flour,0.25,cup,$0.60/lb,$0.04,$0.47
Biscuits n Chicken Gravy,Biscuit,Baking Powder,0.13,tbsp,$4.50/lb,$0.01,
Biscuits n Chicken Gravy,Biscuit,Salt,0.13,tbsp,$0.75/lb,$0.00,
Biscuits n Chicken Gravy,Biscuit,Butter,1.00,tbsp,$2.55/lb,$0.08,
Biscuits n Chicken Gravy,Biscuit,Buttermilk,0.13,cup,$4.00/gal,$0.26,
Biscuits n Chicken Gravy,Chicken Gravy,Chicken Drippings,2.00,tbsp,$0.00 (byproduct),$0.00,$1.00
Biscuits n Chicken Gravy,Chicken Gravy,Butter,2.00,tbsp,$2.55/lb,$0.16,
Biscuits n Chicken Gravy,Chicken Gravy,Flour,0.25,cup,$0.60/lb,$0.04,
Biscuits n Chicken Gravy,Chicken Gravy,Whole Milk,2.00,cup,$2.75/gal,$1.37,
Biscuits n Chicken Gravy,Chicken Gravy,Salt,1.00,tbsp,$0.75/lb,$0.02,
Biscuits n Chicken Gravy,Chicken Gravy,Black Pepper,1.00,tbsp,$8.00/lb,$0.20,
Biscuits n Chicken Gravy,Chicken Gravy,Chicken Boullion,1.00,tsp,$6.00/lb,$0.04,
"Total per Biscuits n Chicken Gravy Portion",-, -, -, -, -, -, **$1.47**
4 pc Tenders,Fried Chicken Tenderloins,Chicken Breast,0.50,lb,$3.00/lb,$1.50,$1.95
4 pc Tenders,Fried Chicken Tenderloins,Dill Pickle Juice,0.25,cup,$5.00/gal,$0.10,
4 pc Tenders,Fried Chicken Tenderloins,Egg,0.25,egg,$0.21/egg,$0.05,
4 pc Tenders,Fried Chicken Tenderloins,Whole Milk,0.13,cup,$2.75/gal,$0.09,
4 pc Tenders,Fried Chicken Tenderloins,Franks Red Hot,0.25,tbsp,$13.50/gal,$0.03,
4 pc Tenders,Fried Chicken Tenderloins,Powdered Sugar,0.50,tbsp,$0.75/lb,$0.01,
4 pc Tenders,Fried Chicken Tenderloins,Paprika,0.25,tbsp,$7.00/lb,$0.04,
4 pc Tenders,Fried Chicken Tenderloins,Salt,0.25,tbsp,$0.75/lb,$0.00,
4 pc Tenders,Fried Chicken Tenderloins,Black Pepper,0.25,tbsp,$8.00/lb,$0.05,
4 pc Tenders,Fried Chicken Tenderloins,Garlic Salt,0.25,tbsp,$5.25/lb,$0.04,
4 pc Tenders,Fried Chicken Tenderloins,Frying Oil,-,-,Negligible,$0.00,
"Total per 4 pc Tenders Portion",-, -, -, -, -, -, **$1.95**
Chicken Sandwich,Fried Chicken Cutlet,Chicken Breast,0.50,lb,$3.00/lb,$1.50,$1.95
Chicken Sandwich,Fried Chicken Cutlet,Dill Pickle Juice,0.25,cup,$5.00/gal,$0.10,
Chicken Sandwich,Fried Chicken Cutlet,Egg,0.25,egg,$0.21/egg,$0.05,
Chicken Sandwich,Fried Chicken Cutlet,Whole Milk,0.13,cup,$2.75/gal,$0.09,
Chicken Sandwich,Fried Chicken Cutlet,Franks Red Hot,0.25,tbsp,$13.50/gal,$0.03,
Chicken Sandwich,Fried Chicken Cutlet,Powdered Sugar,0.50,tbsp,$0.75/lb,$0.01,
Chicken Sandwich,Fried Chicken Cutlet,Paprika,0.25,tbsp,$7.00/lb,$0.04,
Chicken Sandwich,Fried Chicken Cutlet,Salt,0.25,tbsp,$0.75/lb,$0.00,
Chicken Sandwich,Fried Chicken Cutlet,Black Pepper,0.25,tbsp,$8.00/lb,$0.05,
Chicken Sandwich,Fried Chicken Cutlet,Garlic Salt,0.25,tbsp,$5.25/lb,$0.04,
Chicken Sandwich,Fried Chicken Cutlet,Frying Oil,-,-,Negligible,$0.00,
Chicken Sandwich,Sandwich Bun,Sandwich Buns,1.00,sandwich bun,$0.30/each,$0.30,$0.35
Chicken Sandwich,Sandwich Bun,Butter,0.50,tbsp,$2.55/lb,$0.04,
Chicken Sandwich,Dill Pickle Chips,Dill Pickles,0.01,gallon jar,$20.00/gal jar,$0.20,$0.20
"Total per Chicken Sandwich Portion",-, -, -, -, -, -, **$2.50**
Chicken n Dumplings,Dumpling Broth,Chicken Broth,4.00,cup,$1.50/gal,$1.88,$2.41
Chicken n Dumplings,Dumpling Broth,Salt,0.25,tbsp,$0.75/lb,$0.00,
Chicken n Dumplings,Dumpling Broth,Pepper,0.25,tbsp,$8.00/lb,$0.05,
Chicken n Dumplings,Dumpling Broth,Chicken Breast,0.25,lb,$3.00/lb,$0.75,
Chicken n Dumplings,Dumpling Broth,Carrot,1.25,oz,$0.50/lb ($0.04/oz),$0.05,
Chicken n Dumplings,Dumpling Broth,Celery,1.25,oz,$0.50/lb ($0.04/oz),$0.05,
Chicken n Dumplings,Dumpling Broth,Yellow Onion,0.50,oz,$0.50/lb ($0.04/oz),$0.02,
Chicken n Dumplings,Dumplings,Flour,0.50,cup,$0.60/lb,$0.08,$0.95
Chicken n Dumplings,Dumplings,Baking Powder,0.25,tbsp,$4.50/lb,$0.03,
Chicken n Dumplings,Dumplings,Salt,0.25,tbsp,$0.75/lb,$0.00,
Chicken n Dumplings,Dumplings,Butter,2.00,tbsp,$2.55/lb,$0.16,
Chicken n Dumplings,Dumplings,Buttermilk,0.25,cup,$4.00/gal,$0.50,
"Total per Chicken n Dumplings Portion",-, -, -, -, -, -, **$3.36**
Family Combo,Rotisserie Chicken,Whole Chicken,2.25,lb,$1.65/lb,$3.71,$4.01
Family Combo,Rotisserie Chicken,Olive Oil,1.50,tbsp,$0.20/oz (~$0.10/tbsp),$0.15,
Family Combo,Rotisserie Chicken,Salt,1.00,tbsp,$0.75/lb,$0.02,
Family Combo,Rotisserie Chicken,Pepper,1.00,tbsp,$8.00/lb,$0.20,
Family Combo,Rotisserie Chicken,Garlic Salt,1.00,tbsp,$5.25/lb,$0.16,
Family Combo,Rotisserie Chicken,Parsley,1.00,tbsp,$6.00/lb,$0.10,
Family Combo,Rotisserie Chicken,Rosemary,1.00,tbsp,$8.00/lb,$0.13,
Family Combo,Rotisserie Chicken,Butter,1.50,tbsp,$2.55/lb,$0.12,
Family Combo,Dumpling Broth,Chicken Broth,4.00,cup,$1.50/gal,$1.88,$2.41
Family Combo,Dumpling Broth,Salt,0.25,tbsp,$0.75/lb,$0.00,
Family Combo,Dumpling Broth,Pepper,0.25,tbsp,$8.00/lb,$0.05,
Family Combo,Dumpling Broth,Chicken Breast,0.25,lb,$3.00/lb,$0.75,
Family Combo,Dumpling Broth,Carrot,1.25,oz,$0.50/lb ($0.04/oz),$0.05,
Family Combo,Dumpling Broth,Celery,1.25,oz,$0.50/lb ($0.04/oz),$0.05,
Family Combo,Dumpling Broth,Yellow Onion,0.50,oz,$0.50/lb ($0.04/oz),$0.02,
Family Combo,Dumplings,Flour,0.50,cup,$0.60/lb,$0.08,$0.95
Family Combo,Dumplings,Baking Powder,0.25,tbsp,$4.50/lb,$0.03,
Family Combo,Dumplings,Salt,0.25,tbsp,$0.75/lb,$0.00,
Family Combo,Dumplings,Butter,2.00,tbsp,$2.55/lb,$0.16,
Family Combo,Dumplings,Buttermilk,0.25,cup,$4.00/gal,$0.50,
"Total per Family Combo Portion",-, -, -, -, -, -, **$7.37**
Wedges,Potato Wedges,Potatoes,1.00,potato,$0.80/lb (~$0.50 each),$0.50,$0.80
Wedges,Potato Wedges,Whole Milk,0.25,cup,$2.75/gal,$0.17,
Wedges,Potato Wedges,Egg,0.25,egg,$0.21/egg,$0.05,
Wedges,Potato Wedges,Flour,0.25,cup,$0.60/lb,$0.04,
Wedges,Potato Wedges,Cornstarch,0.50,tbsp,$0.80/lb,$0.01,
Wedges,Potato Wedges,Seasoned Salt,0.25,tbsp,$5.25/lb,$0.04,
Wedges,Potato Wedges,Black Pepper,0.25,tbsp,$8.00/lb,$0.05,
Wedges,Potato Wedges,Garlic Salt,0.25,tbsp,$5.25/lb,$0.04,
Wedges,Potato Wedges,Paprika,0.25,tbsp,$7.00/lb,$0.04,
Wedges,Potato Wedges,Parsley,0.25,tbsp,$6.00/lb,$0.03,
Wedges,Potato Wedges,Frying Oil,-,-,Negligible,$0.00,
"Total per Wedges Portion",-, -, -, -, -, -, **$0.80**
Chicken Gravy,Chicken Gravy,Chicken Drippings,1.00,tbsp,$0.00 (byproduct),$0.00,$0.62
Chicken Gravy,Chicken Gravy,Butter,1.00,tbsp,$2.55/lb,$0.08,
Chicken Gravy,Chicken Gravy,Flour,0.13,cup,$0.60/lb,$0.02,
Chicken Gravy,Chicken Gravy,Whole Milk,1.00,cup,$2.75/gal,$0.68,
Chicken Gravy,Chicken Gravy,Salt,0.50,tbsp,$0.75/lb,$0.01,
Chicken Gravy,Chicken Gravy,Black Pepper,0.50,tbsp,$8.00/lb,$0.10,
Chicken Gravy,Chicken Gravy,Chicken Boullion,0.50,tsp,$6.00/lb,$0.02,
"Total per Chicken Gravy Portion",-, -, -, -, -, -, **$0.62**
Biscuits,Biscuit,Flour,0.25,cup,$0.60/lb,$0.04,$0.47
Biscuits,Biscuit,Baking Powder,0.13,tbsp,$4.50/lb,$0.01,
Biscuits,Biscuit,Salt,0.13,tbsp,$0.75/lb,$0.00,
Biscuits,Biscuit,Butter,1.00,tbsp,$2.55/lb,$0.08,
Biscuits,Biscuit,Buttermilk,0.13,cup,$4.00/gal,$0.26,
"Total per Biscuits Portion",-, -, -, -, -, -, **$0.47**
Soda,Soda,Soda (can),1.00,can,$0.50/can,$0.50,$0.50
Soda,Soda,Ice,-,-,Negligible,$0.00,
"Total per Soda Portion",-, -, -, -, -, -, **$0.50**
Water,Water,Water (bottle),1.00,bottle,$0.80/bottle,$0.80,$0.80
Water,Water,Ice,-,-,Negligible,$0.00,
"Total per Water Portion",-, -, -, -, -, -, **$0.80**
Sweet Tea,Sweet Tea,Sweet Tea (bottle),1.00,bottle,$0.80/bottle,$0.80,$0.80
Sweet Tea,Sweet Tea,Ice,-,-,Negligible,$0.00,
"Total per Sweet Tea Portion",-, -, -, -, -, -, **$0.80**
"""

# ================================================
# 3. Create folder if it doesn't exist
# ================================================
output_dir = os.path.dirname(output_path)
if output_dir and not os.path.exists(output_dir):
    os.makedirs(output_dir)
    print(f"Created folder: {output_dir}")

# ================================================
# 4. Load, clean, and save
# ================================================
try:
    df = pd.read_csv(StringIO(csv_text))
    df['Amount per Portion'] = pd.to_numeric(df['Amount per Portion'], errors='coerce')
    df['Cost per Portion Amount'] = pd.to_numeric(df['Cost per Portion Amount'].str.replace('[\$,]', '', regex=True), errors='coerce')
    df['Subtotal per Component'] = pd.to_numeric(df['Subtotal per Component'].str.replace('[\$,*]', '', regex=True), errors='coerce')

    with pd.ExcelWriter(output_path, engine='openpyxl') as writer:
        df.to_excel(writer, index=False, sheet_name='Cost Breakdown')
        workbook = writer.book
        worksheet = writer.sheets['Cost Breakdown']
        for row in worksheet.iter_rows(min_row=2, max_row=worksheet.max_row):
            if row[0].value and 'Total per' in str(row[0].value):
                for cell in row:
                    cell.font = cell.font.copy(bold=True)

    print(f"SUCCESS! Excel saved to:\n   {output_path}")
    print(f"   Timestamp: {pd.Timestamp.now().strftime('%Y-%m-%d %I:%M %p')}")

except Exception as e:
    print(f"ERROR: {e}")
# Out:
# SUCCESS! Excel saved to:
#    C:/Users/user/workspace/c11/Capstone/Data/food_truck_cost_breakdown.xlsx
#    Timestamp: 2025-11-11 03:08 PM
# C:\Users\user\AppData\Local\Temp\ipykernel_8424\2383809229.py:174: DeprecationWarning: Call to deprecated function copy (Use copy(obj) or cell.obj = cell.obj + other).
#   cell.font = cell.font.copy(bold=True)
